# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
number = np.arange(1,34)

# %%
total_time = [
1.906000787878788,
1.8602134848484848,
1.6054464848484848,
1.8999312121212122,
1.9348131212121211,
1.860581606060606,
1.8286326666666666,
1.8305559090909092,
1.7169125454545455,
1.8774489696969696,
1.8743725757575758,
1.8090973636363636,
1.716632303030303,
1.9493588181818182,
1.657709303030303,
1.8505049393939395,
1.5881067575757575,
1.7936143636363637,
1.6870358181818181,
1.665775909090909,
1.7576975757575757,
1.7629969090909092,
1.8370737272727273,
1.736142212121212,
1.7388065757575757,
1.6079385454545454,
1.6430698787878788,
1.6472214242424243,
1.5217732121212122,
1.6823303333333333,
1.6446345454545455,
1.7775419393939393,
1.8854097272727273
]

# %%
downtime = [
1.8141045151515152,
1.7099562121212122,
1.516881212121212,
1.7323434242424243,
1.8442384242424243,
1.7498287575757576,
1.6834836666666666,
1.7375612727272727,
1.580217,
1.764736,
1.7804026666666668,
1.688925090909091,
1.5650879696969697,
1.79691,
1.5680818484848484,
1.742268696969697,
1.4932726666666667,
1.6381984242424243,
1.5928731212121212,
1.568046909090909,
1.6403125151515152,
1.664472393939394,
1.7451093333333334,
1.6408237575757576,
1.6097532424242424,
1.4591977272727272,
1.5242360606060605,
1.5520206363636364,
1.4287110606060607,
1.5869835151515153,
1.5476085454545454,
1.6838348787878787,
1.7683443333333333
]

# %%
data_time = [
1.8141045151515152,
1.7099562121212122,
1.516881212121212,
1.7323434242424243,
1.8442384242424243,
1.7498287575757576,
1.6834836666666666,
1.7375612727272727,
1.580217,
1.764736,
1.7804026666666668,
1.688925090909091,
1.5650879696969697,
1.79691,
1.5680818484848484,
1.742268696969697,
1.4932726666666667,
1.6381984242424243,
1.5928731212121212,
1.568046909090909,
1.6403125151515152,
1.664472393939394,
1.7451093333333334,
1.6408237575757576,
1.6097532424242424,
1.4591977272727272,
1.5242360606060605,
1.5520206363636364,
1.4287110606060607,
1.5869835151515153,
1.5476085454545454,
1.6838348787878787,
1.7683443333333333
]

# %%
somma = 0
avg = 0 
for v in time2:
    somma = somma + v
avgDowntime = somma / len(time2)

# %%
def mediaTot(number):
   return (number/number)*avgTotalTime
y1 = mediaTot(number)
plt.title("Durata Totale del Processo di Migrazione")
plt.xlabel("Iterazione n.")
plt.ylabel("Tempo medio (s)")
plt.plot(number, time, marker='o', label="Tempo totale")
plt.plot(number,y1, label="AvgTot")
plt.legend()

# %%
plt.title("Durata Totale e Downtime")
plt.xlabel("Iterazione n.")
plt.ylabel("Tempo medio (s)")
plt.plot(number, total_time, marker='o', label="Tempo totale")
plt.plot(number, downtime, marker='o', color="green", label="Downtime")
plt.legend()
