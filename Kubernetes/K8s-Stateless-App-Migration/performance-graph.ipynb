# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
number = np.arange(1,34)

# %%
time = [1.7174647575757576,
2.8253943333333336,
3.6378304242424244,
2.259706303030303,
1.7535371212121211,
1.6023908484848486,
1.7181714242424242,
1.6606004545454545,
1.7220464848484849,
2.6272944242424243,
2.6852014545454543,
2.152354696969697,
1.7790316060606062,
1.8647702424242425,
1.5508430606060606,
1.7340490909090909,
1.681247393939394,
1.7804400303030303,
1.7685726363636363,
1.5604411818181818,
1.6905178181818181,
1.848653212121212,
2.186134878787879,
1.5607406666666668,
1.7024252727272726,
1.7299132727272728,
1.741688606060606,
1.8278697575757576,
1.615227090909091,
1.6440970606060605,
1.7575262727272727,
1.6889052727272726,
1.8690719393939395]

# %%
time2 = [1.6114006363636364,
2.5711101212121212,
3.3158378787878786,
2.1664278484848483,
1.6634086060606061,
1.5098240606060607,
1.6287779090909091,
1.570193303030303,
1.6269651818181818,
2.5156090303030303,
2.582928606060606,
2.0436798181818183,
1.633046090909091,
1.7083537878787878,
1.4604741212121213,
1.6322238181818183,
1.5897739696969697,
1.6297944848484849,
1.5878353636363636,
1.4670871818181819,
1.6024500303030302,
1.7598412727272728,
2.077958,
1.448949515151515,
1.5894782424242424,
1.6379435757575758,
1.5653342121212122,
1.7371311212121212,
1.5244639090909091,
1.5538489393939394,
1.6683104545454546,
1.562195818181818,
1.6075274848484848]

# %%
somma = 0
avg = 0 
for v in time:
    somma = somma + v
avgTotalTime = somma / len(time)

# %%
somma = 0
avg = 0 
for v in time2:
    somma = somma + v
avgDowntime = somma / len(time2)

# %%
def mediaTot(number):
   return (number/number)*avgTotalTime
y1 = mediaTot(number)
plt.title("Durata Totale del Processo di Migrazione")
plt.xlabel("Iterazione n.")
plt.ylabel("Tempo medio (s)")
plt.plot(number, time, marker='o', label="Tempo totale")
plt.plot(number,y1, label="AvgTot")
plt.legend()

# %%
def mediaDown(number):
   return (number/number)*avgDowntime
y2 = mediaDown(number)
plt.title("Downtime del Servizio Durante il Processo di Migrazione")
plt.xlabel("Iterazione n.")
plt.ylabel("Tempo medio (s)")
plt.plot(number, time2, marker='o', color="green", label="Downtime")
plt.plot(number,y2, label="AvgDowntime")
plt.legend()

# %%
plt.title("Durata Totale e Downtime")
plt.xlabel("Iterazione n.")
plt.ylabel("Tempo medio (s)")
plt.plot(number, time, marker='o', label="Tempo totale")
plt.plot(number, time2, marker='o', color="green", label="Downtime")
plt.legend()
